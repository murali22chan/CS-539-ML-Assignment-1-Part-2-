# %% [markdown]
# <a href="https://colab.research.google.com/github/murali22chan/CS-539-ML-Assignment-1-Part-2-/blob/main/ML%20Assignment%201%20(Part%202.2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
col_names = ["Name","Debt","Income","Married?","Owns_Property","Gender","Risk"]

# %%
df = pd.read_csv("creditCardData(2.2).csv")

# %%
features = ["Debt","Income","Married?","Owns_Property","Gender"]

X = df[features]
Y= df[['Risk']]

# %%
clf = DecisionTreeClassifier(criterion= "entropy")

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
ohe.fit(X)
X_train_ohe = ohe.transform(X).toarray()

ohe_df = pd.DataFrame(X_train_ohe, columns=ohe.get_feature_names(X.columns))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
clf = clf.fit(X_train_ohe, Y)

# %%
from matplotlib import pyplot as plt
from sklearn import tree

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (3,3), dpi=300)
tree.plot_tree(clf,
               feature_names = ohe_df.columns, 
               class_names=np.unique(Y).astype('str'),
               filled = True)
plt.show()
